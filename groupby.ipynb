# %%
import pandas as pd
import statistics as st
import matplotlib.pyplot as plt
import numpy as nm
import datetime
df = pd.read_excel("C:\\Users\\sartv\\YandexDisk\\Porg\\Py\\P1\\direct.xlsx")
df.columns
# Out:
# Index(['Дата', 'Кампания', '№ Кампании', 'Показы', 'Клики', 'CTR (%)',
#        'Расход (руб.)', 'Ср. цена клика (руб.)', 'Ср. ставка за клик (руб.)',
#        'Ср. позиция показов', 'Конверсии'],
#       dtype='object')

# %%
pnp_krr_conv = df.loc[df['№ Кампании'] == 57733902, ['Конверсии']]
pnp_rnd_conv = df.loc[df['№ Кампании'] == 57733910, ['Конверсии']]
pnp_ptg_conv = df.loc[df['№ Кампании'] == 57733916, ['Конверсии']]
mx_pp_krr_conv = nm.mean(pnp_krr_conv)
mx_pp_krr_conv #0.56
mx_pp_rnd_conv = nm.mean(pnp_rnd_conv)
mx_pp_rnd_conv #0.40
mx_pp_ptg_conv = nm.mean(pnp_ptg_conv)
mx_pp_ptg_conv #0.40
# Out:
# C:\Users\sartv\AppData\Roaming\Python\Python39\site-packages\numpy\core\fromnumeric.py:3472: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# Конверсии    4.131579
# dtype: float64

# %%
pnp_rnd_conv = df.loc[(df['№ Кампании'] == 57733916) & (df['Конверсии'] > 0)]
pnp_rnd_conv
# Out:
#             Дата                        Кампания  № Кампании  Показы  Клики  \
# 3350  30.07.2021  Пеноплекс / Поиск /  Пятигорск    57733916     128     30
# 4634  14.10.2021  Пеноплекс / Поиск /  Пятигорск    57733916      81     14
# 4658  15.10.2021  Пеноплекс / Поиск /  Пятигорск    57733916      86     13
# 4682  18.10.2021  Пеноплекс / Поиск /  Пятигорск    57733916     121     16
# 4706  19.10.2021  Пеноплекс / Поиск /  Пятигорск    57733916      78     15
# ...          ...                             ...         ...     ...    ...
# 6795  09.03.2022  Пеноплекс / Поиск /  Пятигорск    57733916     102     13
# 6818  10.03.2022  Пеноплекс / Поиск /  Пятигорск    57733916     113     17
# 6841  11.03.2022  Пеноплекс / Поиск /  Пятигорск    57733916      84      9
# 6864  14.03.2022  Пеноплекс / Поиск /  Пятигорск    57733916      97     18
# 6910  16.03.2022  Пеноплекс / Поиск /  Пятигорск    57733916      98     13
#
#       CTR (%)  Расход (руб.)  Ср. цена клика (руб.)  \
# ...
