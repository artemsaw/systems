# %%
import pandas as pd
import statistics as st
import matplotlib.pyplot as plt
import numpy as nm
import datetime
df = pd.read_excel("C:\\Users\\artem\\YandexDisk\\Porg\\Py\\stsystem\\direct.xlsx")
df.head(4)
# Out:
#         data                         company  number_company  impressions  \
# 0 2020-12-25  Пеноплекс / Поиск /  Краснодар        57733902           46
# 1 2020-12-25     Пеноплекс / Поиск /  Ростов        57733910           49
# 2 2020-12-25  Пеноплекс / Поиск /  Пятигорск        57733916            8
# 3 2020-12-25     Базальт / Поиск / Краснодар        57733919           19
#
#    clicks    ctr    cost  avg_clck  avg_bid  avg_pos  conv
# 0       9  19.57  126.07     14.01    35.65     2.95     0
# 1       7  14.29   86.57     12.37    32.73     2.07     0
# 2       0   0.00    0.00      0.00     0.00     1.57     0
# 3       5  26.32   76.98     15.40    32.18     2.62     0

# %%
#компания с самой высокой ценой цели
conv_cost = df.cost.idxmax()
dvcads = df.loc[conv_cost, "cost"]
# Out:
# 5093.15

# %%
df['company'].map({'Пеноплекс / Поиск / Ростов':57733910, 'Пеноплекс / Поиск / Пятигорск':57733916})
# Out:
#            data                          company  number_company  impressions  \
# 0    2020-12-25   Пеноплекс / Поиск /  Краснодар        57733902           46
# 1    2020-12-25      Пеноплекс / Поиск /  Ростов        57733910           49
# 2    2020-12-25   Пеноплекс / Поиск /  Пятигорск        57733916            8
# 3    2020-12-25      Базальт / Поиск / Краснодар        57733919           19
# 4    2020-12-25         Базальт / Поиск / Ростов        57733930           14
# ...         ...                              ...             ...          ...
# 6943 2022-03-17  Гидроизоляция / Поиск /  Ростов        58099999            9
# 6944 2022-03-17       Проф. мембрана / Краснодар        59366016            2
# 6945 2022-03-17         Стекловата / Краснодар /        59367619            1
# 6946 2022-03-17         Пеноплекс / Поиск / Крым        68628168            8
# 6947 2022-03-17           Базальт / Поиск / Крым        69775818            2
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6948 entries, 0 to 6947
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   data            6948 non-null   datetime64[ns]
#  1   company         6948 non-null   object
#  2   number_company  6948 non-null   int64
#  3   impressions     6948 non-null   int64
#  4   clicks          6948 non-null   int64
#  5   ctr             6948 non-null   float64
#  6   cost            6948 non-null   float64
#  7   avg_clck        6948 non-null   float64
#  8   avg_bid         6948 non-null   float64
#  9   avg_pos         6948 non-null   float64
#  10  conv            6948 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(4), object(1)
# memory usage: 597.2+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6948 entries, 0 to 6947
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   data            6948 non-null   datetime64[ns]
#  1   company         6948 non-null   object
#  2   number_company  6948 non-null   int64
#  3   impressions     6948 non-null   int64
#  4   clicks          6948 non-null   int64
#  5   ctr             6948 non-null   float64
#  6   cost            6948 non-null   float64
#  7   avg_clck        6948 non-null   float64
#  8   avg_bid         6948 non-null   float64
#  9   avg_pos         6948 non-null   float64
#  10  conv            6948 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(4), object(1)
# memory usage: 597.2+ KB

# %%
pd.DataFrame({
    'Missing': df.isna().sum(),
    'Missing(%)': (df.isna().sum() / df.shape[0]) * 100
}).sort_values(by='Missing', ascending=False)
# Out:
#                 Missing  Missing(%)
# data                  0         0.0
# company               0         0.0
# number_company        0         0.0
# impressions           0         0.0
# clicks                0         0.0
# ctr                   0         0.0
# cost                  0         0.0
# avg_clck              0         0.0
# avg_bid               0         0.0
# avg_pos               0         0.0
# conv                  0         0.0

# %%
print(f'Missing cells: {df.isna().sum().sum()}')
print(f'Missing cells(%): {round((df.isna().sum().sum() / (df.shape[0] * df.shape[1])) * 100, 2)}%')
# Out:
# Missing cells: 0
# Missing cells(%): 0.0%

# %%
df.duplicated().sum()
# <удаление всех дубликатов из таблицы df специальным методом>
# df = df.drop_duplicates().reset_index(drop=True)
# Out:
# 0

# %% [markdown]
# Прверка гипотезы о том, что день недели вляиет на конверсию.

# %%
df['weekday'] = df['data'].dt.day_name()

# %%
df.groupby('weekday')['conv'].count()
# Out:
# weekday
# Friday       1367
# Monday       1273
# Saturday       88
# Sunday         54
# Thursday     1402
# Tuesday      1374
# Wednesday    1390
# Name: conv, dtype: int64

# %%
df.groupby('weekday')['conv'].count()
# Out:
# weekday
# Friday       1367
# Monday       1273
# Saturday       88
# Sunday         54
# Thursday     1402
# Tuesday      1374
# Wednesday    1390
# Name: conv, dtype: int64
